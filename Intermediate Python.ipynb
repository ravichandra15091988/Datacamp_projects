# %% [markdown]
# ## Logic, Control Flow, and Filtering

# %%
2 > 3
# Out:
# False

# %%
3 > 2
# Out:
# True

# %%
2 == 3
# Out:
# False

# %%
2>=3
# Out:
# False

# %%
3<=2
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
'carl'<'chris'
# Out:
# True

# %%
'chris'<'carl'
# Out:
# False

# %%
x = 12
x > 5 and x < 112
# Out:
# True

# %% [markdown]
# ## Working with Numpy

# %%
import numpy as np

bmi = np.array([21.852, 20.975, 21.75, 24.757, 21.441])
np.logical_and(bmi > 21, bmi < 25)
bmi[np.logical_and(bmi > 21, bmi < 25)]
# Out:
# array([21.852, 21.75 , 24.757, 21.441])

# %% [markdown]
# ## Conditional Statements - If, else, if

# %%
z = 19
if z % 2 == 0:
    print('z is even')
elif z % 3 == 0:
    print('z is divisible by 3')

else:
    print('z is odd')
# Out:
# z is odd

# %%
d = {'country':['Brazil', 'Russia', 'India'],
'capital':['Brasilia', 'Moscow', 'New Delhi'],
'area':[8.516, 17.10, 3.286],
'population':[200.4, 143.5, 1252]}
import pandas as pd
brics = pd.DataFrame(d)
#To specify the row index
brics.index = ['BR', 'RU', 'IN']
brics
# Out:
#    country    capital    area  population
# BR  Brazil   Brasilia   8.516       200.4
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0

# %%
brics[brics['area'] < 8]
# Out:
#    country    capital   area  population
# IN   India  New Delhi  3.286      1252.0

# %%
brics[np.logical_and(brics['area']> 8, brics['area'] < 10)]
# Out:
#    country   capital   area  population
# BR  Brazil  Brasilia  8.516       200.4

# %%
error = 50.0
while error > 1:
    error = error/4
    print(error)
# Out:
# 12.5
# 3.125
# 0.78125

# %%
fam = [1.73, 1.68, 1.71, 1.89]
for height in fam:
    print(height)
# Out:
# 1.73
# 1.68
# 1.71
# 1.89

# %%
for index, height in enumerate(fam):
    print(index, height)
# Out:
# 0 1.73
# 1 1.68
# 2 1.71
# 3 1.89

# %%
for c in "family":
    print(c)
# Out:
# f
# a
# m
# i
# l
# y

# %%
house = [['Hallway', 200.09], ['Kitchen', 112.4],['Living Room', 344.2],['Bedroom', 322.2],['Bathroom', 122.4]]
for room in house:
    print('the ' + room[0] + ' is ' + str(room[1]) + ' sq.m')
# Out:
# the Hallway is 200.09 sq.m
# the Kitchen is 112.4 sq.m
# the Living Room is 344.2 sq.m
# the Bedroom is 322.2 sq.m
# the Bathroom is 122.4 sq.m

# %% [markdown]
# ## Looping Data Structures

# %%
## Dictionaries: for key, value in my_dict.items()
## Numpy Array: for val in np.nditer(my_array)
## DataFrame: for lab, row in my_df.iterrows()

# %%
world = {'Afghanistan': 2.34, 'Albania': 4.38, 'Algeria': 3.88}
for key, value in world.items():
    print(key + ' -- ' + str(value))
# Out:
# Afghanistan -- 2.34
# Albania -- 4.38
# Algeria -- 3.88

# %%
np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])

bmi = np_height/np_weight ** 2
for val in bmi:
    print(val)
# Out:
# 0.00040447399676420793
# 0.00047936449963476984
# 0.00042274830900676394
# 0.0002418562273499723
# 0.00037926219730533147

# %%
means = np.array([np_height, np_weight])
for val in np.nditer(means):
    print(val)
# Out:
# 1.73
# 1.68
# 1.71
# 1.89
# 1.79
# 65.4
# 59.2
# 63.6
# 88.4
# 68.7

# %%
for val in brics:
    print(val)
# Out:
# country
# capital
# area
# population

# %%
for lab, row in brics.iterrows():
    print(lab, row)
# Out:
# BR country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object
# RU country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object
# IN country           India
# capital       New Delhi
# area              3.286
# population       1252.0
# Name: IN, dtype: object

# %%
for lab, row in brics.iterrows():
    print(lab +' : '+ row['country'])
# Out:
# BR : Brazil
# RU : Russia
# IN : India

# %%
for lab, row in brics.iterrows():
    brics[lab, 'name_lenght'] = len(row['country'])
brics
# Out:
#    country    capital    area  population  (BR, name_lenght)  \
# BR  Brazil   Brasilia   8.516       200.4                  6
# RU  Russia     Moscow  17.100       143.5                  6
# IN   India  New Delhi   3.286      1252.0                  6
#
#     (RU, name_lenght)  (IN, name_lenght)
# BR                  6                  5
# RU                  6                  5
# IN                  6                  5

# %%
brics['name_length'] = brics['country'].apply(len)
brics
# Out:
#    country    capital    area  population  (BR, name_lenght)  \
# BR  Brazil   Brasilia   8.516       200.4                  6
# RU  Russia     Moscow  17.100       143.5                  6
# IN   India  New Delhi   3.286      1252.0                  6
#
#     (RU, name_lenght)  (IN, name_lenght)  name_length
# BR                  6                  5            6
# RU                  6                  5            6
# IN                  6                  5            5

# %%
cars['COUNTRY'] = cars['country'].apply(str.upper)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 cars['COUNTRY'] = cars['country'].apply(str.upper)
#
# NameError: name 'cars' is not defined

# %% [markdown]
# ## Case Study: Hacker Statistics

# %%
## Generate Random numbers
np.random.seed(123)

# %%
np.random.rand(123)
# Out:
# array([0.55131477, 0.71946897, 0.42310646, 0.9807642 , 0.68482974,
#        0.4809319 , 0.39211752, 0.34317802, 0.72904971, 0.43857224,
#        0.0596779 , 0.39804426, 0.73799541, 0.18249173, 0.17545176,
#        0.53155137, 0.53182759, 0.63440096, 0.84943179, 0.72445532,
#        0.61102351, 0.72244338, 0.32295891, 0.36178866, 0.22826323,
#        0.29371405, 0.63097612, 0.09210494, 0.43370117, 0.43086276,
#        0.4936851 , 0.42583029, 0.31226122, 0.42635131, 0.89338916,
#        0.94416002, 0.50183668, 0.62395295, 0.1156184 , 0.31728548,
#        0.41482621, 0.86630916, 0.25045537, 0.48303426, 0.98555979,
#        0.51948512, 0.61289453, 0.12062867, 0.8263408 , 0.60306013,
#        0.54506801, 0.34276383, 0.30412079, 0.41702221, 0.68130077,
#        0.87545684, 0.51042234, 0.66931378, 0.58593655, 0.6249035 ,
#        0.67468905, 0.84234244, 0.08319499, 0.76368284, 0.24366637,
#        0.19422296, 0.57245696, 0.09571252, 0.88532683, 0.62724897,
#        0.72341636, 0.01612921, 0.59443188, 0.55678519, 0.15895964,
#        0.15307052, 0.69552953, 0.31876643, 0.6919703 , 0.55438325,
#        0.38895057, 0.92513249, 0.84167   , 0.35739757, 0.04359146,
#        0.30476807, 0.39818568, 0.70495883, 0.99535848, 0.35591487,
#        0.76254781, 0.59317692, 0.6917018 , 0.15112745, 0.39887629,
#        0.2408559 , 0.34345601, 0.51312815, 0.66662455, 0.10590849,
#        0.13089495, 0.32198061, 0.66156434, 0.84650623, 0.55325734,
#        0.85445249, 0.38483781, 0.3167879 , 0.35426468, 0.17108183,
#        0.82911263, 0.33867085, 0.55237008, 0.57855147, 0.52153306,
#        0.00268806, 0.98834542, 0.90534158, 0.20763586, 0.29248941,
#        0.52001015, 0.90191137, 0.98363088])

# %%
np.random.randint(123)
# Out:
# 58

# %%
np.random.seed()
step = 50
dice = np.random.randint(1,7)

## Finish the control to construct

if dice <=2:
    step = step - 1
elif dice < 6:
    step = step + 1
else:
    step = step + np.random.randint(1,7) 
    
print(dice)
print(step)
# Out:
# 6
# 53

# %%
# Import numpy and set seed
import numpy as np
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        # use max to make sure step can't go below 0
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60]

# %%
## Visualize random_walk
import matplotlib.pyplot as plt
plt.plot(random_walk)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        # Implement clumsiness (there is a 0.001 chance that the climber will fall and restart from 0 step)
        if np.random.rand(0, 1) <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

np_aw = np.array(all_walks) # Convert all_walks to Numpy array: np_aw
plt.plot(np_aw)
plt.show()

np_aw_t = np.transpose(np_aw)# Transpose np_aw: np_aw_t. This will make each row contains the 1st, 2nd, 3rd... random step in all the random walks.
plt.plot(np_aw_t)
plt.show()

ends = np_aw_t[-1] # Select last row from np_aw_t: ends
plt.hist(ends)# Plot histogram of ends, display plot
plt.show()
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_7364\2983946554.py:17: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if np.random.rand(0, 1) <= 0.001 :
